# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Load the flight data from the CSV file
data = pd.read_csv("/home/mona/Downloads/Airline Delay.csv")

# Step 2: Extract the features (exclude non-numeric columns if any)
X = data.select_dtypes(include=['number']).dropna()

# Step 3: Standardize the data (important for PCA)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 4: Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# a) How many components did PCA generate when you first run the analysis?
num_components = pca.n_components_
print("Number of components generated by PCA:", num_components)

# b) Provide a table of feature weights for each component
feature_weights = pd.DataFrame(pca.components_, columns=X.columns)
print("\nFeature weights for each component:")
print(feature_weights)

# c) How many components would you keep and why?
# You can decide based on the explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance_ratio = explained_variance_ratio.cumsum()
threshold_variance = 0.95  # Adjust as needed

num_components_to_keep = (cumulative_variance_ratio < threshold_variance).sum() + 1
print("\nNumber of components to keep for", threshold_variance, "variance:", num_components_to_keep)

# d) Using answers from (b) and (c), which features would you keep?
# You would keep the top 'num_components_to_keep' components, which correspond to the most important features.
# You can also decide to keep a specific number of components based on your analysis goals.
# Out:
# Number of components generated by PCA: 17
#
# Feature weights for each component:
#             year         month   arr_flights     arr_del15    carrier_ct  \
# 0  -4.291873e-02  2.220446e-16  2.886033e-01  3.070089e-01  2.846988e-01
# 1   9.542835e-02 -5.551115e-17  4.043960e-02 -4.413332e-03  8.468640e-02
# 2   7.580660e-01 -6.938894e-17  6.402122e-02 -8.743423e-02  2.025095e-02
# 3   6.003996e-01  4.163336e-17 -1.175478e-02  8.059772e-02 -7.267850e-02
# 4  -1.302085e-01  1.387779e-17 -2.215120e-01 -1.541772e-01 -2.787799e-01
# 5   1.204427e-01 -1.387779e-16  1.909341e-01  6.697090e-02  2.588353e-01
# 6  -2.166541e-03 -4.813858e-17  6.661517e-02  2.933872e-02 -4.829845e-02
# 7  -1.450040e-01 -3.330669e-16  4.034466e-01  1.993977e-02  3.507153e-01
# 8   1.824151e-02  2.844947e-16 -4.490121e-01 -1.318890e-01  2.568775e-01
# 9   5.350549e-03 -1.092876e-16  1.150512e-01 -4.586844e-03 -1.063291e-01
# 10 -1.099584e-02 -1.873501e-16  2.473939e-01  3.961728e-02 -3.809982e-04
# 11 -2.547226e-02 -4.093947e-16  3.709880e-01 -2.009842e-01 -6.193341e-01
# 12  1.147429e-02  7.389922e-16 -4.904895e-01  2.597600e-01  1.769417e-03
# 13  1.238678e-02  6.938894e-17 -6.197838e-02  8.615672e-02 -3.406127e-01
# 14  3.032343e-08 -1.659998e-13 -6.789527e-07 -8.531079e-01  2.432029e-01
# 15  3.565506e-17 -8.324095e-04  6.190673e-16  1.643274e-12 -4.684434e-13
# 16  7.412704e-17 -9.999997e-01 -7.729545e-16  1.404564e-13 -4.008683e-14
#
#       weather_ct        nas_ct   security_ct  late_aircraft_ct  arr_cancelled  \
# 0   2.432109e-01  2.786017e-01  1.794710e-01      2.899143e-01   2.306818e-01
# 1  -1.878338e-01 -8.867213e-02  6.250830e-01      2.383815e-02  -2.558543e-02
# 2   3.628560e-01 -1.382052e-01  3.436363e-02     -1.375596e-01   5.360341e-02
# 3  -3.870931e-01  2.907013e-01 -8.252672e-02      6.473627e-03   1.580125e-01
# 4   2.731900e-02 -2.806808e-02  1.290611e-01     -1.726732e-01   3.344152e-01
